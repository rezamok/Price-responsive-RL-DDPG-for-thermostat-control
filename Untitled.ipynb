# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
with open('actions.txt', 'rb') as f:
    actions = pickle.load(f)
with open('delta_ts.txt', 'rb') as f:
    delta_ts = pickle.load(f)

# %%
plt.plot(actions)

# %%
plt.plot(delta_ts)

# %%
plt.subplot(211)
plt.plot(actions[9900:10100])
plt.axvline(100,color = 'black')
plt.subplot(212)
plt.plot(delta_ts[9900:10100])
plt.axvline(100,color = 'black')

# %%
print(np.max(delta_ts))
# Out:
# 0.02438763154670596

# %%
print(0.05*0.02)
# Out:
# 0.001

# %%
with open('actions_nof.txt', 'rb') as f:
    actions = pickle.load(f)
with open('delta_ts_nof.txt', 'rb') as f:
    delta_ts = pickle.load(f)

# %%
plt.subplot(211)
plt.plot(actions[9900:10100])
plt.axvline(100,color = 'black')
plt.subplot(212)
plt.plot(delta_ts[9900:10100])
plt.axvline(100,color = 'black')

# %%
plt.plot(delta_ts)

# %%
plt.plot(actions)

# %%
print(np.max(delta_ts[:10000]))
print(0.02/np.max(delta_ts[:10000]))
# Out:
# 0.005659217894230073
# 3.534057244975715

# %%
with open('actions_nof2.txt', 'rb') as f:
    actions = pickle.load(f)
with open('delta_ts_nof2.txt', 'rb') as f:
    delta_ts = pickle.load(f)

# %%
plt.subplot(211)
plt.plot(actions[9900:10100])
plt.axvline(100,color = 'black')
plt.subplot(212)
plt.plot(delta_ts[9900:10100])
plt.axvline(100,color = 'black')

# %%
with open('actor_loss.txt', 'rb') as f:
    actor_loss = pickle.load(f)
with open('critic_loss.txt', 'rb') as f:
    critic_loss = pickle.load(f)
with open('actions_accr.txt', 'rb') as f:
    actions = pickle.load(f)
with open('delta_ts_accr.txt', 'rb') as f:
    delta_ts = pickle.load(f)

# %%
plt.plot(actor_loss[:20])

# %%
plt.plot(actor_loss[:2000])

# %%
y = [actor_loss[i]*2-actor_loss[i-1] for i in range(1,len(actor_loss))]
y = [actor_loss[0]] + y
plt.plot(y)

# %%
plt.plot(critic_loss[:2000])

# %%
plt.plot(actions[10000:])

# %%
plt.plot(delta_ts[10000:])

# %%
plt.subplot(211)
plt.plot(actions[9900:10100])
plt.axvline(100,color = 'black')
plt.subplot(212)
plt.plot(delta_ts[9900:10100])
plt.axvline(100,color = 'black')
